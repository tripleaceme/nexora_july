# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
root_path = Path("/Users/mac/Documents/Amdari/Amdari/Nexora_Health/nexora-caresync-pipeline/data/source")

# %%
df_conditions = pd.read_csv(root_path / "conditions.csv")
df_encounters = pd.read_csv(root_path / "encounters.csv")
df_organizations = pd.read_csv(root_path / "organizations.csv")
df_patients = pd.read_csv(root_path / "patients.csv")
df_payers = pd.read_csv(root_path / "payers.csv")
df_providers = pd.read_csv(root_path / "providers.csv")

# %%
df_list = {"Conditions": df_conditions,
            "Encounters": df_encounters,
              "Organizations": df_organizations,
                "Patients": df_patients, 
                "Payers": df_payers, 
                "Providers": df_providers}

for name, df in df_list.items():
    print(f"Dataset: {name}")
    print("================================")
    print(f"Shape of {df.shape[0]} rows and {df.shape[1]} columns")
    print("================================")
    print(df.head())
    print("================================")
    print(df.info())

# %%
df_conditions.head(2)
# Out:
#         START        STOP                               PATIENT  \
# 0  2016-01-30  2017-06-17  fe621c76-a591-b7be-5668-b77f00240d82
# 1  2016-12-17  2016-12-30  fe621c76-a591-b7be-5668-b77f00240d82
#
#                               ENCOUNTER                  SYSTEM       CODE  \
# 0  fe621c76-a591-b7be-bd84-05fbbefb22b4  http://snomed.info/sct  160968000
# 1  fe621c76-a591-b7be-ac26-b3481f6a2205  http://snomed.info/sct   10509002
#
#                            DESCRIPTION
# 0  Risk activity involvement (finding)
# 1          Acute bronchitis (disorder)

# %%
df_encounters.head(2)
# Out:
#                                      Id                 START  \
# 0  fe621c76-a591-b7be-bd84-05fbbefb22b4  2016-01-30T22:47:14Z
# 1  fe621c76-a591-b7be-ac26-b3481f6a2205  2016-12-17T13:47:14Z
#
#                    STOP                               PATIENT  \
# 0  2016-01-30T23:02:14Z  fe621c76-a591-b7be-5668-b77f00240d82
# 1  2016-12-17T14:02:14Z  fe621c76-a591-b7be-5668-b77f00240d82
#
#                            ORGANIZATION                              PROVIDER  \
# 0  39c15c0f-5c49-311e-99d2-1fb99d80e06e  4017bd91-3e46-3ba5-a9ec-58fddb0a8778
# 1  6cf8a214-8d57-3267-85e5-7719e15cd63e  29e69e63-32ee-385c-a255-b20e0e70755c
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  df166300-5a78-3502-a46a-832842197811       wellness  410620009
# 1  df166300-5a78-3502-a46a-832842197811     ambulatory  185345009
#
#                          DESCRIPTION  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  \
# ...

# %%
df_organizations.head(2)
# Out:
#                                      Id                         NAME  \
# 0  74ab949d-17ac-3309-83a0-13b4405c66aa  Fitchburg Outpatient Clinic
# 1  324b4137-57a0-3ae0-89db-1c33f57ae0c1         LOWN ACQUISITION LLC
#
#            ADDRESS           CITY STATE       ZIP        LAT        LON  \
# 0  881 Main Street      Fitchburg    MA      1420  42.586487 -71.805210
# 1     134 NORTH ST  NORTH READING    MA  18641315  42.589234 -71.105465
#
#                           PHONE  REVENUE  UTILIZATION
# 0  978-342-9781 Or 978-342-9781      0.0          128
# 1                    7818262393      0.0            1

# %%
df_patients.head(2)
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  fe621c76-a591-b7be-5668-b77f00240d82  2001-12-29       NaN  999-83-4938
# 1  5f01f823-c8e8-9e40-c911-54b7b1ad843a  1969-07-11       NaN  999-24-3495
#
#      DRIVERS    PASSPORT PREFIX       FIRST     MIDDLE          LAST  ...  \
# 0  S99928423  X60273823X    Ms.  Malvina930  Leonia336      Rohan584  ...
# 1  S99940334  X33132045X   Mrs.      Min362        NaN  McDermott739  ...
#
#      CITY          STATE          COUNTY     FIPS   ZIP        LAT        LON  \
# 0  Boston  Massachusetts  Suffolk County  25025.0  2118  42.292643 -71.062912
# 1  Milton  Massachusetts  Norfolk County  25021.0  2186  42.272783 -71.043757
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 0             5891.27           298460.31   11272
# 1           189706.47           685859.80  179290
#
# [2 rows x 28 columns]

# %%
df_payers.head(2)
# Out:
#                                      Id      NAME   OWNERSHIP  ADDRESS  CITY  \
# 0  a735bf55-83e9-331a-899d-a82a60b9f60c  Medicare  GOVERNMENT      NaN   NaN
# 1  df166300-5a78-3502-a46a-832842197811  Medicaid  GOVERNMENT      NaN   NaN
#
#    STATE_HEADQUARTERED  ZIP  PHONE  AMOUNT_COVERED  AMOUNT_UNCOVERED  ...  \
# 0                  NaN  NaN    NaN      8086375.96         753385.17  ...
# 1                  NaN  NaN    NaN     13562117.16         265696.13  ...
#
#    UNCOVERED_ENCOUNTERS  COVERED_MEDICATIONS  UNCOVERED_MEDICATIONS  \
# 0                     0                 3304                      0
# 1                     0                 1552                      0
#
#    COVERED_PROCEDURES  UNCOVERED_PROCEDURES  COVERED_IMMUNIZATIONS  \
# 0                8788                     0                    702
# 1                8019                     0                   1117
#
#    UNCOVERED_IMMUNIZATIONS  UNIQUE_CUSTOMERS  QOLS_AVG  MEMBER_MONTHS
# ...

# %%
df_providers.head(2)
# Out:
#                                      Id                          ORGANIZATION  \
# 0  6abe8000-c6a9-3404-a8f4-bd77c2a3e7c5  74ab949d-17ac-3309-83a0-13b4405c66aa
# 1  3d404795-f269-3ee8-9b46-b43c8c80a118  324b4137-57a0-3ae0-89db-1c33f57ae0c1
#
#                         NAME GENDER        SPECIALITY          ADDRESS  \
# 0       Gabriel934 Reilly981      F  GENERAL PRACTICE  881 Main Street
# 1  Marquis364 Satterfield305      M  GENERAL PRACTICE     134 NORTH ST
#
#             CITY STATE       ZIP        LAT        LON  ENCOUNTERS  PROCEDURES
# 0      Fitchburg    MA      1420  42.586487 -71.805210         128           0
# 1  NORTH READING    MA  18641315  42.589234 -71.105465           1           0

# %%
df_patients.head(2)
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  fe621c76-a591-b7be-5668-b77f00240d82  2001-12-29       NaN  999-83-4938
# 1  5f01f823-c8e8-9e40-c911-54b7b1ad843a  1969-07-11       NaN  999-24-3495
#
#      DRIVERS    PASSPORT PREFIX       FIRST     MIDDLE          LAST  ...  \
# 0  S99928423  X60273823X    Ms.  Malvina930  Leonia336      Rohan584  ...
# 1  S99940334  X33132045X   Mrs.      Min362        NaN  McDermott739  ...
#
#      CITY          STATE          COUNTY     FIPS   ZIP        LAT        LON  \
# 0  Boston  Massachusetts  Suffolk County  25025.0  2118  42.292643 -71.062912
# 1  Milton  Massachusetts  Norfolk County  25021.0  2186  42.272783 -71.043757
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 0             5891.27           298460.31   11272
# 1           189706.47           685859.80  179290
#
# [2 rows x 28 columns]

# %%
df_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   113 non-null    object
#  1   BIRTHDATE            113 non-null    object
#  2   DEATHDATE            15 non-null     object
#  3   SSN                  113 non-null    object
#  4   DRIVERS              95 non-null     object
#  5   PASSPORT             92 non-null     object
#  6   PREFIX               93 non-null     object
#  7   FIRST                113 non-null    object
#  8   MIDDLE               93 non-null     object
#  9   LAST                 113 non-null    object
#  10  SUFFIX               2 non-null      object
#  11  MAIDEN               36 non-null     object
#  12  MARITAL              82 non-null     object
#  13  RACE                 113 non-null    object
#  14  ETHNICITY            113 non-null    object
# ...

# %%
df_patients_cl = df_patients.copy()

# %%
df_patients_cl.head(2)
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  fe621c76-a591-b7be-5668-b77f00240d82  2001-12-29       NaN  999-83-4938
# 1  5f01f823-c8e8-9e40-c911-54b7b1ad843a  1969-07-11       NaN  999-24-3495
#
#      DRIVERS    PASSPORT PREFIX       FIRST     MIDDLE          LAST  ...  \
# 0  S99928423  X60273823X    Ms.  Malvina930  Leonia336      Rohan584  ...
# 1  S99940334  X33132045X   Mrs.      Min362        NaN  McDermott739  ...
#
#      CITY          STATE          COUNTY     FIPS   ZIP        LAT        LON  \
# 0  Boston  Massachusetts  Suffolk County  25025.0  2118  42.292643 -71.062912
# 1  Milton  Massachusetts  Norfolk County  25021.0  2186  42.272783 -71.043757
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 0             5891.27           298460.31   11272
# 1           189706.47           685859.80  179290
#
# [2 rows x 28 columns]

# %%
# Trim the ID column to retain only the last elements when splitted by -
df_patients_cl["Id"] = df_patients_cl["Id"].str.split("-").str[-1]

# %%
# Convert the "BIRTHDATE" column to datetime format, handling errors by coercing invalid formats to NaT (Not a Time).
df_patients_cl["BIRTHDATE"] = pd.to_datetime(df_patients_cl["BIRTHDATE"], errors='coerce')

# %%
# convert deathdate to datetime format, handling errors by coercing invalid formats to NaT (Not a Time).
df_patients_cl["DEATHDATE"] = pd.to_datetime(df_patients_cl["DEATHDATE"], errors='coerce')

# %%
# drop ssn, drivers, passpor and prefix columns from the dataframe as they are not needed for further analysis.
df_patients_cl.drop(columns=["SSN", "DRIVERS", "PASSPORT", "PREFIX"], inplace=True)

# %%
# fill missing values in marital with unknown as it is a categorical variable and we don't want to lose any data.
df_patients_cl["MARITAL"].fillna("Unknown", inplace=True)
# Out:
# /var/folders/nh/kprmp5xn57l72mppyplsnj100000gq/T/ipykernel_9350/1881352881.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_patients_cl["MARITAL"].fillna("Unknown", inplace=True)

# %%
# strip off the numbers in the first, middle and last name columns to retain only the alphabetic characters.
df_patients_cl["FIRST"] = df_patients_cl["FIRST"].str.replace(r'\d+', '', regex=True)
df_patients_cl["MIDDLE"] = df_patients_cl["MIDDLE"].str.replace(r'\d+', '', regex=True)
df_patients_cl["LAST"] = df_patients_cl["LAST"].str.replace(r'\d+', '', regex=True)

# %%
# combine first, middle and last name columns into a single column called "FULL_NAME"
df_patients_cl["FULL_NAME"] = df_patients_cl[["FIRST", "MIDDLE", "LAST"]].apply(lambda x: ' '.join(x.dropna()), axis=1)

# %%
# drop first, middle and last name columns as they are no longer needed after creating the FULL_NAME column.
# drop suffix and maiden name columns as they are not needed for further analysis.
df_patients_cl.drop(columns=["FIRST", "MIDDLE", "LAST", "SUFFIX", "MAIDEN"], inplace=True)

# %%
# Replace all missing values of Marital status with unknown as it is a categorical variable and we don't want to lose any data.
df_patients_cl["MARITAL"] = df_patients_cl["MARITAL"].map({"M": "Married", "S": "Single",
                                                            "D": "Divorced", "W": "Widowed","Unknown": "Unknown"})

# %%
df_patients_cl.head(2)
# Out:
#              Id  BIRTHDATE DEATHDATE  MARITAL   RACE    ETHNICITY GENDER  \
# 0  b77f00240d82 2001-12-29       NaT  Unknown  white  nonhispanic      F
# 1  54b7b1ad843a 1969-07-11       NaT  Married  white  nonhispanic      F
#
#                   BIRTHPLACE                    ADDRESS    CITY  \
# 0  Hudson  Massachusetts  US       119 King Lock Apt 20  Boston
# 1  Conway  Massachusetts  US  764 Hudson Ferry Suite 54  Milton
#
#            STATE          COUNTY     FIPS   ZIP        LAT        LON  \
# 0  Massachusetts  Suffolk County  25025.0  2118  42.292643 -71.062912
# 1  Massachusetts  Norfolk County  25021.0  2186  42.272783 -71.043757
#
#    HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  INCOME             FULL_NAME
# 0              5891.27            298460.31   11272  Malvina Leonia Rohan
# 1            189706.47            685859.80  179290         Min McDermott

# %% [markdown]
#  print out a list of all unknown marital status that the deathdate is not null, which means the patient is dead but the marital status is unknown.
# df_patients_cl[(df_patients_cl["MARITAL"] == "Unknown") & (df_patients_cl["DEATHDATE"].notnull())]

# %%
# Standardize the "RACE", "ETHNICITY" columns by converting all values to title case (first letter capitalized) for consistency.
df_patients_cl["RACE"] = df_patients_cl["RACE"].str.title()
df_patients_cl["ETHNICITY"] = df_patients_cl["ETHNICITY"].str.title()

# %%
# Map the "GENDER" column values from "M" and "F" to "Male" and "Female" respectively for clarity and consistency
df_patients_cl["GENDER"] = df_patients_cl["GENDER"].map({"M": "Male", "F": "Female"})

# %%
# update the birthplace for patient with the Id c93095b90340 to Shanghai  
# Shanghai-Municipality  CN so as to have a consistent format for all the birthplace values.
df_patients_cl.loc[df_patients_cl["Id"] == "c93095b90340", "BIRTHPLACE"] = "Shanghai  Shanghai-Municipality  CN"

# %%
df_patients_cl.head(2)
# Out:
#              Id  BIRTHDATE DEATHDATE  MARITAL   RACE    ETHNICITY  GENDER  \
# 0  b77f00240d82 2001-12-29       NaT  Unknown  White  Nonhispanic  Female
# 1  54b7b1ad843a 1969-07-11       NaT  Married  White  Nonhispanic  Female
#
#                   BIRTHPLACE                    ADDRESS    CITY  \
# 0  Hudson  Massachusetts  US       119 King Lock Apt 20  Boston
# 1  Conway  Massachusetts  US  764 Hudson Ferry Suite 54  Milton
#
#            STATE          COUNTY     FIPS   ZIP        LAT        LON  \
# 0  Massachusetts  Suffolk County  25025.0  2118  42.292643 -71.062912
# 1  Massachusetts  Norfolk County  25021.0  2186  42.272783 -71.043757
#
#    HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  INCOME             FULL_NAME
# 0              5891.27            298460.31   11272  Malvina Leonia Rohan
# 1            189706.47            685859.80  179290         Min McDermott

# %%
# split the "BIRTHPLACE" column into three separate columns: "BIRTHPLACE_CITY", "BIRTHPLACE_STATE", 
# and "BIRTHPLACE_COUNTRY" by splitting the string on spaces and extracting the respective parts.

df_patients_cl["BIRTHPLACE_CITY"] = df_patients_cl["BIRTHPLACE"].str.split(" ").str[0]
df_patients_cl["BIRTHPLACE_STATE"] = df_patients_cl["BIRTHPLACE"].str.split(" ").str[2]
df_patients_cl["BIRTHPLACE_COUNTRY"] = df_patients_cl["BIRTHPLACE"].str.split(" ").str[4]

# %%
df_patients_cl.head(2)
# Out:
#              Id  BIRTHDATE DEATHDATE  MARITAL   RACE    ETHNICITY  GENDER  \
# 0  b77f00240d82 2001-12-29       NaT  Unknown  White  Nonhispanic  Female
# 1  54b7b1ad843a 1969-07-11       NaT  Married  White  Nonhispanic  Female
#
#                   BIRTHPLACE                    ADDRESS    CITY  ...   ZIP  \
# 0  Hudson  Massachusetts  US       119 King Lock Apt 20  Boston  ...  2118
# 1  Conway  Massachusetts  US  764 Hudson Ferry Suite 54  Milton  ...  2186
#
#          LAT        LON  HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  INCOME  \
# 0  42.292643 -71.062912              5891.27            298460.31   11272
# 1  42.272783 -71.043757            189706.47            685859.80  179290
#
#               FULL_NAME  BIRTHPLACE_CITY  BIRTHPLACE_STATE BIRTHPLACE_COUNTRY
# 0  Malvina Leonia Rohan           Hudson     Massachusetts                 US
# 1         Min McDermott           Conway     Massachusetts                 US
#
# [2 rows x 23 columns]

# %%
# drop birthplace column as it is no longer needed after creating the BIRTHPLACE_CITY, BIRTHPLACE_STATE and BIRTHPLACE_COUNTRY columns.
df_patients_cl.drop(columns=["BIRTHPLACE"], inplace=True)

# Rename resident to the city, state and country columns name to have a consistent format for all the birthplace values.
df_patients_cl.rename(columns={"CITY": "RESIDENT_CITY", 
                               "STATE": "RESIDENT_STATE", 
                               "COUNTY": "RESIDENT_COUNTY"}, inplace=True)

# %%
# Convert the "FIPS" column to string type to ensure consistency in data type for further analysis.
df_patients_cl['FIPS'] = df_patients_cl['FIPS'].astype(str)

# %%
# Read the missing FIPS codes from the CSV file into a DataFrame called fill_fips.
fill_fips = pd.read_csv(root_path / "missing_fips.csv")

# %%
fill_fips.head()
# Out:
#               county  fips_code
# 0  Barnstable County      25001
# 1     Bristol County      25005
# 2    Plymouth County      25023
# 3   Middlesex County      25017
# 4   Worcester County      25027

# %%
# Merge the df_patients_cl DataFrame with the fill_fips DataFrame on the "RESIDENT_COUNTY" column from df_patients_cl and the "county" column from fill_fips.
# For testing purposes, we will only merge the first 10 rows of df_patients_cl with fill_fips to check if the merge is working correctly.
missing_fips = df_patients_cl[["RESIDENT_STATE", "RESIDENT_COUNTY", "FIPS"]]

# %%
missing_fips
# Out:
#     RESIDENT_STATE   RESIDENT_COUNTY     FIPS
# 0    Massachusetts    Suffolk County  25025.0
# 1    Massachusetts    Norfolk County  25021.0
# 2    Massachusetts    Norfolk County  25021.0
# 3    Massachusetts      Essex County  25009.0
# 4    Massachusetts  Middlesex County      nan
# ..             ...               ...      ...
# 108  Massachusetts  Middlesex County  25017.0
# 109  Massachusetts  Middlesex County  25017.0
# 110  Massachusetts    Bristol County  25005.0
# 111  Massachusetts   Plymouth County      nan
# 112  Massachusetts   Plymouth County  25023.0
#
# [113 rows x 3 columns]

# %%
# Merge the missing_fips DataFrame with the fill_fips DataFrame on the "RESIDENT_COUNTY" column from missing_fips and the "county" column from fill_fips.
df_fips = missing_fips.merge(
    fill_fips,
    how='left',
    left_on='RESIDENT_COUNTY',
    right_on='county'
)

# %%
df_fips
# Out:
#     RESIDENT_STATE   RESIDENT_COUNTY     FIPS            county  fips_code
# 0    Massachusetts    Suffolk County  25025.0               NaN        NaN
# 1    Massachusetts    Norfolk County  25021.0               NaN        NaN
# 2    Massachusetts    Norfolk County  25021.0               NaN        NaN
# 3    Massachusetts      Essex County  25009.0      Essex County    25009.0
# 4    Massachusetts  Middlesex County      nan  Middlesex County    25017.0
# ..             ...               ...      ...               ...        ...
# 108  Massachusetts  Middlesex County  25017.0  Middlesex County    25017.0
# 109  Massachusetts  Middlesex County  25017.0  Middlesex County    25017.0
# 110  Massachusetts    Bristol County  25005.0    Bristol County    25005.0
# 111  Massachusetts   Plymouth County      nan   Plymouth County    25023.0
# 112  Massachusetts   Plymouth County  25023.0   Plymouth County    25023.0
#
# [113 rows x 5 columns]

# %%
# Merge the df_patients_cl DataFrame with the fill_fips DataFrame on the "RESIDENT_COUNTY" column from df_patients_cl and the "county" column from fill_fips.
df_patients_cl = df_patients_cl.merge(
    fill_fips,
    how='left',
    left_on='RESIDENT_COUNTY',
    right_on='county'
)

# %%
df_patients_cl.head(2)
# Out:
#              Id  BIRTHDATE DEATHDATE  MARITAL   RACE    ETHNICITY  GENDER  \
# 0  b77f00240d82 2001-12-29       NaT  Unknown  White  Nonhispanic  Female
# 1  54b7b1ad843a 1969-07-11       NaT  Married  White  Nonhispanic  Female
#
#                      ADDRESS RESIDENT_CITY RESIDENT_STATE  ...        LON  \
# 0       119 King Lock Apt 20        Boston  Massachusetts  ... -71.062912
# 1  764 Hudson Ferry Suite 54        Milton  Massachusetts  ... -71.043757
#
#   HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  INCOME             FULL_NAME  \
# 0             5891.27            298460.31   11272  Malvina Leonia Rohan
# 1           189706.47            685859.80  179290         Min McDermott
#
#    BIRTHPLACE_CITY  BIRTHPLACE_STATE  BIRTHPLACE_COUNTRY county fips_code
# 0           Hudson     Massachusetts                  US    NaN       NaN
# 1           Conway     Massachusetts                  US    NaN       NaN
#
# [2 rows x 24 columns]

# %%
# drop county column as it is no longer needed after merging with the fill_fips dataframe.
df_patients_cl.drop(columns=["county"], inplace=True)

# %%
df_patients_cl.head(2)
# Out:
#              Id  BIRTHDATE DEATHDATE  MARITAL   RACE    ETHNICITY  GENDER  \
# 0  b77f00240d82 2001-12-29       NaT  Unknown  White  Nonhispanic  Female
# 1  54b7b1ad843a 1969-07-11       NaT  Married  White  Nonhispanic  Female
#
#                      ADDRESS RESIDENT_CITY RESIDENT_STATE  ...        LAT  \
# 0       119 King Lock Apt 20        Boston  Massachusetts  ...  42.292643
# 1  764 Hudson Ferry Suite 54        Milton  Massachusetts  ...  42.272783
#
#          LON  HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  INCOME  \
# 0 -71.062912              5891.27            298460.31   11272
# 1 -71.043757            189706.47            685859.80  179290
#
#               FULL_NAME  BIRTHPLACE_CITY  BIRTHPLACE_STATE BIRTHPLACE_COUNTRY  \
# 0  Malvina Leonia Rohan           Hudson     Massachusetts                 US
# 1         Min McDermott           Conway     Massachusetts                 US
#
#   fips_code
# 0       NaN
# 1       NaN
#
# [2 rows x 23 columns]

# %%
# drop the .0 from the FIPS column values to ensure consistency in the format of the FIPS codes.
df_patients_cl["FIPS"] = df_patients_cl["FIPS"].str.replace(r'\.0$', '', regex=True)

# %%
# create another version control of df_patients_cl
final_df = df_patients_cl.copy()

# %%
final_df["FIPS"].replace("nan", np.nan, inplace=True)
# Out:
# /var/folders/nh/kprmp5xn57l72mppyplsnj100000gq/T/ipykernel_9350/1582324099.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df["FIPS"].replace("nan", np.nan, inplace=True)

# %%
final_df.isna().sum()
# Out:
# Id                      0
# BIRTHDATE               0
# DEATHDATE              98
# MARITAL                 0
# RACE                    0
# ETHNICITY               0
# GENDER                  0
# ADDRESS                 0
# RESIDENT_CITY           0
# RESIDENT_STATE          0
# RESIDENT_COUNTY         0
# FIPS                   24
# ZIP                     0
# LAT                     0
# LON                     0
# HEALTHCARE_EXPENSES     0
# HEALTHCARE_COVERAGE     0
# INCOME                  0
# FULL_NAME               0
# BIRTHPLACE_CITY         0
# BIRTHPLACE_STATE        0
# BIRTHPLACE_COUNTRY      0
# fips_code              37
# dtype: int64

# %%
# Replcae the missing values in the "FIPS" column with the corresponding values from the "fips_code" column obtained from the fill_fips DataFrame.
final_df["FIPS"].fillna(final_df["fips_code"], inplace=True)
# Out:
# /var/folders/nh/kprmp5xn57l72mppyplsnj100000gq/T/ipykernel_9350/726619886.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df["FIPS"].fillna(final_df["fips_code"], inplace=True)

# %%
final_df.isna().sum()
# Out:
# Id                      0
# BIRTHDATE               0
# DEATHDATE              98
# MARITAL                 0
# RACE                    0
# ETHNICITY               0
# GENDER                  0
# ADDRESS                 0
# RESIDENT_CITY           0
# RESIDENT_STATE          0
# RESIDENT_COUNTY         0
# FIPS                    0
# ZIP                     0
# LAT                     0
# LON                     0
# HEALTHCARE_EXPENSES     0
# HEALTHCARE_COVERAGE     0
# INCOME                  0
# FULL_NAME               0
# BIRTHPLACE_CITY         0
# BIRTHPLACE_STATE        0
# BIRTHPLACE_COUNTRY      0
# fips_code              37
# dtype: int64

# %%
# drop fips_code column as it is no longer needed after filling the missing values in the "FIPS" column.
final_df.drop(columns=["fips_code"], inplace=True)

# %%
new_col = [
    "Id", "BIRTHDATE", "DEATHDATE", "FULL_NAME", "MARITAL", "RACE",
    "ETHNICITY", "GENDER", "ADDRESS", "RESIDENT_CITY", "RESIDENT_STATE", "RESIDENT_COUNTY",
    "BIRTHPLACE_CITY", "BIRTHPLACE_STATE", "BIRTHPLACE_COUNTRY", "FIPS", "ZIP", "LAT",
    "LON", "HEALTHCARE_EXPENSES", "HEALTHCARE_COVERAGE", "INCOME"
]

# %%
set(final_df.columns) == set(new_col)
# Out:
# True

# %%
set(new_col) - set(final_df.columns)
# Out:
# set()

# %%
# rearrange the columns of the final_df DataFrame to match the order specified in the new_col list.
final_df = final_df.loc[:, new_col]

# %%
final_df.head()
# Out:
#              Id  BIRTHDATE DEATHDATE                   FULL_NAME  MARITAL  \
# 0  b77f00240d82 2001-12-29       NaT        Malvina Leonia Rohan  Unknown
# 1  54b7b1ad843a 1969-07-11       NaT               Min McDermott  Married
# 2  d56a20511339 1997-03-28       NaT          Asa Rene Schroeder  Married
# 3  536444ee049b 1973-11-15       NaT               Lewis Kautzer   Single
# 4  c93095b90340 1999-11-19       NaT  Jamison Garland Gusikowski  Unknown
#
#     RACE    ETHNICITY  GENDER                    ADDRESS RESIDENT_CITY  ...  \
# 0  White  Nonhispanic  Female       119 King Lock Apt 20        Boston  ...
# 1  White  Nonhispanic  Female  764 Hudson Ferry Suite 54        Milton  ...
# 2  White  Nonhispanic    Male       519 Ziemann Overpass      Franklin  ...
# 3  White     Hispanic  Female  461 Keebler Meadow Apt 13       Danvers  ...
# 4  Asian  Nonhispanic    Male       886 Kshlerin Passage       Sudbury  ...
#
# ...

# %%
# rename the columns of the final_df DataFrame to lowercase for a consistent format for all the column names.
final_df.columns = final_df.columns.str.lower()

# %%
# load the data into postgres database with the credential nexora as username and password. 
# The database name is nexora and the table name is patients.

import psycopg2
from sqlalchemy import create_engine
conn = psycopg2.connect(
    host="localhost",
    database="nexora_health",
    user="nexora",
    password="nexora_dev"
)

engine = create_engine('postgresql+psycopg2://nexora:nexora_dev@localhost/nexora_health')

final_df.to_sql('patients', engine, if_exists='append', index=False)
# Out:
# 113
